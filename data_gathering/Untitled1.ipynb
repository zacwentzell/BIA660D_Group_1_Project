# %%
import requests
from bs4 import BeautifulSoup as bs
import urllib3
import time 
import random
from string import digits

# %%
url_base='https://www.yelp.com/search?find_desc=Restaurants&find_loc=Hoboken%2C+NJ&start='

# %%
url_base
# Out:
# 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Hoboken%2C+NJ&start='

# %%
remove_digits=str.maketrans('','',digits)

# %%
res_name_list=[]
res_number=0

while res_number <= 680:
    
    final_url=url_base+str(res_number)
    res=requests.get(final_url)
    soup=bs(res.text,"html5lib")
    solo_res = soup.find_all('div',{'class':'search-result natural-search-result'})
    for solo_ in solo_res:
        #check if the restaurant is in hoboken
        if 'Hoboken' in str(solo_.find('address')):  
            #add name of rest
            res_name=solo_.find_all('span',{'class':'indexed-biz-name'})    
            res_name_list.append(res_name[0].text.replace('.','').translate (remove_digits).strip())
    time.sleep(random.randint(2,4))
    res_number+=10

# %%
res_name_list
# Out:
# ['Grand Vin',
#  'Zack’s Oak Bar & Restaurant',
#  'The Cuban Restaurant and Bar',
#  'Halifax',
#  'Del Frisco’s Grille',
#  'South Street Fish & Ramen Co',
#  'Tutta Pesca',
#  'La Isla Restaurant',
#  'House of Que',
#  'Keming Restaurant',
#  'Cooper’s Union',
#  'Anthony David’s',
#  'Gogi Grill - Hoboken',
#  'La Casa',
#  'Koro Koro',
#  'Onieals',
#  'Pilsener Haus & Biergarten',
#  'Moran’s',
#  'Union Hall',
#  'House of Que',
#  'Sorellina',
#  'Panello',
#  'Fiore Deli of Hoboken',
#  'Blue Eyes Restaurant',
#  'The Shepherd & the Knucklehead',
#  'Mamoun’s Falafel Restaurant',
#  'Frankie & Ava’s Italian Eatery',
#  'Onieals',
#  'Koro Koro',
#  'Hoboken Turtle Club',
#  'Sorellina',
#  'Pilsener Haus & Biergarten',
#  'Union Hall',
#  'Makai Poké',
#  'Blue Eyes Restaurant',
#  'Panello',
#  'Northern Soul',
#  'The Shepherd & the Knucklehead',
#  'Tenth Street Pasta & Pizza',
#  'Birch Hoboken',
#  'Fiore Deli of Hoboken',
#  'Mamoun’s Falafel Restaurant',
#  'Frankie & Ava’s Italian Eatery',
#  'Greektown',
#  'San Giuseppe',
#  'Empanadas Cafe',
#  'Ali Baba',
#  'Carpe Diem Pub & Restaurant',
#  'Elysian Cafe',
#  'Urban Coalhouse Pizza + Bar',
#  'Cafe Matt & Meera',
#  'Flatbread Grill',
#  'City Bistro',
#  'Cafe Matt & Meera',
#  'Okinawa Sushi & Grill',
#  'Cafe Matt & Meera',
#  'Quality Greens Kitchen',
#  'Napoli’s Pizza',
#  'City Bistro',
#  'Arthurs',
#  'Sushi Lounge',
#  'Lola’s',
#  'Grimaldi’s',
#  'Bareburger',
#  'Dino & Harrys Steakhouse',
#  'Lo-Fatt-Chow',
#  'Grubbs Take Away',
#  'Turning Point of Hoboken',
#  'Vivi Bubble Tea',
#  'T Thai',
#  'Cafe Michelina',
#  'Court Street Restaurant & Bar',
#  'th & Willow Bar & Grill',
#  'Gold Roast Cafe',
#  'Fran’s Italian Deli',
#  'Trattoria Saporito',
#  'The Stewed Cow',
#  'Grubbs Take Away',
#  'Midtown Philly Steaks',
#  'Napoli’s Brick Oven Pizza',
#  'Charrito’s',
#  'Lo-Fatt-Chow',
#  'th & Willow Bar & Grill',
#  'Charrito’s',
#  'GFG Bakery',
#  'Vito’s Italian Deli',
#  'Rosticeria Da Gigi',
#  'Sushi Lounge',
#  'Turning Point of Hoboken',
#  'Rosticeria Da Gigi',
#  'Midtown Philly Steaks',
#  'Sushi Lounge',
#  'Green Pear Cafe',
#  'Pho Nomenon Noodle & Grill',
#  'Sushi House',
#  'East LA',
#  'Chicken Factory',
#  'Losurdo’s Italian Bakery & Deli',
#  'Dozzino',
#  'East LA',
#  'Hot House Pizza',
#  'Precious Chinese Cuisine',
#  'Dozzino',
#  'Hot House Pizza',
#  'East LA',
#  'Wicked Wolf Tavern',
#  'Precious Chinese Cuisine',
#  'Tony Boloney’s',
#  'Piccolo’s',
#  'Sri Thai Thai Restaurant',
#  'Ultramarinos',
#  'Baja Mexican Cuisine',
#  'Tony Boloney’s',
#  'Leo’s Grandevous',
#  'Ultramarinos',
#  'Sri Thai Thai Restaurant',
#  'Benny Tudino’s Pizzeria',
#  'Schnackenberg’s Luncheonette',
#  'Baja Mexican Cuisine',
#  'Village Pourhouse',
#  'Number  Chinese Kitchen',
#  'Barbès Restaurant',
#  'Illuzion',
#  'Village Pourhouse',
#  'On the FlipSide',
#  'Illuzion',
#  'Surf Taco',
#  'Hotel Victor Bar & Grill',
#  'Angel’s Recipe Ice Cream & Crepes',
#  'Simply Juiced',
#  'Phoenix Bar and Grille',
#  'th Street Tavern',
#  'Mr Wraps',
#  'Ubu',
#  'Lisa’s Italian Deli',
#  'MONDO - DOGS',
#  'Malibu Diner',
#  'Stacks Pancake House & Cafefudatcsbudrqfscf',
#  'Bangkok City Thai Restaurant',
#  'Ubu',
#  'Ayame Hibachi & Sushi',
#  'Spa Diner',
#  'Mulligan’s',
#  'The Brick Fire Baked Pizza',
#  'Ayame Hibachi & Sushi',
#  'Pizzeria Hoboken',
#  'MONDO - DOGS',
#  'Bluestone Lane',
#  'The Little Grocery Downtown',
#  'McSwiggan’s Pub',
#  'D’s Soul Full Cafe',
#  'MONDO - DOGS',
#  'Rice Shop',
#  'Green Rock Tap & Grill',
#  'Little Market',
#  'La Bouche Cafe',
#  'Black Rail Coffee',
#  'Big Banner Restaurant',
#  'Giovanni’s Pizzeria & Restaurant',
#  'The Dubliner',
#  'Luca Brasi’s Deli',
#  'Farside Bar & Grill',
#  'Torna’s Pizzeria',
#  'McSwiggan’s Pub',
#  'Black Rail Coffee',
#  'The Little Grocery Downtown',
#  'Little Market',
#  'D’s Soul Full Cafe',
#  'Off the Wall Chinese Cuisine',
#  'Big Banner Restaurant',
#  'Cals Hotdogs',
#  'Cals Hotdogs',
#  'La Bouche Cafe',
#  'The Dubliner',
#  'Giovanni’s Pizzeria & Restaurant',
#  'Sunnyside Cafe & Eatery',
#  'Liberty Gourmet',
#  'Imposto’s Pizza',
#  'Raf Deli and Cafe',
#  'Domino’s',
#  'Luca Brasi’s Deli',
#  'Asia Sushi & Chinese Cuisine',
#  'Cluck U Chicken',
#  'Old Lorenzo’s Pizza',
#  'Uptown Pizzeria',
#  'Liberty Gourmet',
#  'The Little Grocery',
#  'Hoboken Hot Bagels',
#  'Raf Deli and Cafe',
#  'Imposto’s Pizza',
#  'Raf Deli and Cafe',
#  'Liberty Gourmet',
#  'Mill’s Tavern',
#  'Venti Pizza',
#  'Imposto’s Pizza',
#  'Wok To Walk',
#  'QDOBA Mexican Eats',
#  'Venti Pizza',
#  'Rome Pizzeria & Grill',
#  'Rome Pizzeria & Grill',
#  'Stars Pizzeria',
#  'Chen’s Kitchen',
#  'Chipotle Mexican Grill',
#  'Wings To Go - Hoboken',
#  'Chen’s Kitchen',
#  'Hoboken Arts and Music Festival',
#  'Bukhari Grill',
#  'Junior’s Papaya Grill',
#  'Bukhari Grill',
#  'Five-O Café',
#  'La Caseta',
#  'Gelato Summer Popup',
#  'Atomic Wings',
#  'Grande Pizza',
#  'Bona Pizza',
#  'Buona Pizza',
#  'Famous Pizza',
#  'Sabrett Hot Dog Stand @ Columbus Park',
#  'Texas BBQ',
#  'McDonald’s',
#  'Piccininni Salumaria',
#  'Sassos Deli & Liqour',
#  'Santa Fe Dog Express',
#  'Positouch Point of Sale Systems',
#  'Subway',
#  'Subway']

# %%
len(set(res_name_list))
# Out:
# 165

# %%
import pandas as pd

# %%
name_df=pd.DataFrame(res_name_list)
name_df.to_csv(r'/Users/heli/Desktop/660-res.csv')

# %%
temp=[i.lower().replace(' ','-') for i in res_name_list]

# %%
temp1=[i.replace('&','and') for i in temp]

# %%
res_final_name=[i.replace("’",'') for i in temp1]

# %%
temp2=[i.replace('---','-') for i in res_final_name]

# %%
temp3=[i.replace('-+-','-') for i in temp2]

# %%
temp4=[i.replace('-@-','-') for i in temp3]

# %%
temp5=[i.replace('--','-') for i in temp4]

# %%
name_df
# Out:
#                                          0
# 0                                Grand Vin
# 1              Zack’s Oak Bar & Restaurant
# 2             The Cuban Restaurant and Bar
# 3                                  Halifax
# 4                      Del Frisco’s Grille
# 5             South Street Fish & Ramen Co
# 6                              Tutta Pesca
# 7                       La Isla Restaurant
# 8                             House of Que
# 9                        Keming Restaurant
# 10                          Cooper’s Union
# 11                         Anthony David’s
# 12                    Gogi Grill - Hoboken
# 13                                 La Casa
# 14                               Koro Koro
# 15                                 Onieals
# 16              Pilsener Haus & Biergarten
# 17                                 Moran’s
# 18                              Union Hall
# 19                            House of Que
# 20                               Sorellina
# 21                                 Panello
# 22                   Fiore Deli of Hoboken
# 23                    Blue Eyes Restaurant
# 24          The Shepherd & the Knucklehead
# 25             Mamoun’s Falafel Restaurant
# 26          Frankie & Ava’s Italian Eatery
# 27                                 Onieals
# 28                               Koro Koro
# 29                     Hoboken Turtle Club
# ..                                     ...
# 196                     QDOBA Mexican Eats
# 197                            Venti Pizza
# 198                  Rome Pizzeria & Grill
# 199                  Rome Pizzeria & Grill
# 200                         Stars Pizzeria
# 201                         Chen’s Kitchen
# 202                 Chipotle Mexican Grill
# 203                  Wings To Go - Hoboken
# 204                         Chen’s Kitchen
# 205        Hoboken Arts and Music Festival
# 206                          Bukhari Grill
# 207                  Junior’s Papaya Grill
# 208                          Bukhari Grill
# 209                            Five-O Café
# 210                              La Caseta
# 211                    Gelato Summer Popup
# 212                           Atomic Wings
# 213                           Grande Pizza
# 214                             Bona Pizza
# 215                            Buona Pizza
# 216                           Famous Pizza
# 217  Sabrett Hot Dog Stand @ Columbus Park
# 218                              Texas BBQ
# 219                             McDonald’s
# 220                   Piccininni Salumaria
# 221                   Sassos Deli & Liqour
# 222                   Santa Fe Dog Express
# 223        Positouch Point of Sale Systems
# 224                                 Subway
# 225                                 Subway
#
# [226 rows x 1 columns]

# %%
res_price_list=[]
for i in range(len(temp5)):
    
     
    url_infor= 'https://www.yelp.com/biz/'+str(temp5[i])+'-hoboken'
    res=requests.get(url_infor)
    soup=bs(res.text,"html5lib")
    res_price=soup.find_all('span',{'class':'business-attribute price-range'})
    res_name=soup.find_all('span',{'class':'indexed-biz-name'})
#     for m in range(len(res_price)):
    try:
        res_price_list.append(res_price[0].text)
    except:
        print(temp5[i])

    time.sleep(random.randint(2,4))
# Out:
# grand-vin
# zacks-oak-bar-and-restaurant
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-203-084e40b1eec3> in <module>()
#      14         print(temp5[i])
#      15 #         temp5.remove([i])
# ---> 16     time.sleep(random.randint(2,4))
#
# KeyboardInterrupt:

# %%
len(res_price_list)
# Out:
# 0

# %%
price_df=pd.DataFrame(res_final_name,res_price_list)

# %%
price_df.to_csv(r'/Users/heli/Desktop/660-price.csv')

# %%
# price_df[::3]
# Out:
#       0
# 0    $$
# 3   $$$
# 6    $$
# 9   $$$
# 12   $$
# 15   $$
# 18  $$$
# 21   $$
# 24   $$
# 27  $$$
# 30   $$
# 33  $$$
# 36   $$
# 39   $$

# %%
list=['a,b,c']
